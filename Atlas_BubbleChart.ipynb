# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
import seaborn as sns

# Create example dataframe
n=30
df = pd.DataFrame({
'x': np.random.rand(27),
'y': np.random.rand(27),
's': [134884/n, 25368/n, 24858/n, 23193/n, 22771/n, 7033/n, 93142/n,  4657/n, 2959/n, 11564/n, 48303/n, 
    32557/n, 185894/n, 25478/n, 32291/n, 2918/n, 52559/n, 40058/n, 5133/n, 1188/n, 47536/n, 3360780/n, 
    355655/n, 28786/n, 48254/n, 2257227/n, 242756/n],
'group': ['Attock', 'Fateh Jhang', 'Hazro', 'Jand', 'Pindi Gheb', 'Bhoun', 'Chakwal', 'Choa Saidan Shah', 'Kallar Kahar', 'Lawa','Talagang', 'Dina', 'Jhelum', 'Khewra', 'Pind Dadan Khan', 'Sohawa', 'Gujjar Khan', 'Kahuta', 'Kallar Saydan', 'Kotli Sattian', 'Murree', 'Islamabad - Rawalpindi', 'Taxila', 'Ali Pur Chatha', 'Gakhar Mandi', 'Gujranwala', 'Kamoki']
})

#Create figure
plt.figure(figsize = (15,10))
    
# Create scatterplot. alpha controls the opacity and s controls the size.
ax = sns.scatterplot(df.x, df.y,  alpha = 0.5,s = df.s)

#plt.xlabel("the X axis")
#plt.ylabel("the Y axis")
plt.title("Population of 27 Cities of Punjab")

#For each point, we add a text inside the bubble
for line in range(0,df.shape[0]):
     ax.text(df.x[line], df.y[line], df.group[line], horizontalalignment='center', size='medium', color='black')
