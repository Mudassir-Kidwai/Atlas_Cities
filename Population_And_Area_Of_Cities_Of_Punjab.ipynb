# %%
#libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# create data
n=100
numberOfCities=27
x = np.random.rand(numberOfCities)
y = x+np.random.rand(numberOfCities)
z = [134884/n, 25368/n, 24858/n, 23193/n, 22771/n, 7033/n, 93142/n,  4657/n, 2959/n, 11564/n, 48303/n, 32557/n, 185894/n, 25478/n, 32291/n, 2918/n, 52559/n, 40058/n, 5133/n, 1188/n, 47536/n, 3360780/n, 
    355655/n, 28786/n, 48254/n, 2257227/n, 242756/n] 

names = ['Attock', 'Fateh Jhang', 'Hazro', 'Jand', 'Pindi Gheb','Bhoun', 'Chakwal', 'Choa Saidan Shah', 'Kallar Kahar', 'Lawa','Talagang', 'Dina', 'Jhelum', 'Khewra', 'Pind Dadan Khan', 'Sohawa', 'Gujjar Khan', 'Kahuta', 'Kallar Saydan', 'Kotli Sattian', 'Murree', 'Islamabad - Rawalpindi', 'Taxila', 'Ali Pur Chatha', 'Gakhar Mandi', 'Gujranwala', 'Kamoki']

plt.figure(figsize = (15,10)) 

#plt.scatter(x,y, s=z, c=x, cmap="Blues", alpha=0.4, label = "check",edgecolors="grey", linewidth=2)
for i in range(numberOfCities):
    plt.scatter(x[i], y[i], s=z[i], alpha=0.5, label=names[i])

# Add titles (main and on axis)
plt.legend(loc="upper left",numpoints=10,markerscale=0.5, fontsize=9)
#plt.xlabel("the X axis")
#plt.ylabel("the Y axis")
plt.title("A colored bubble plot of Cities")
plt.show()

# %%
#libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# create data
n=100
numberOfCities=9
x = np.random.rand(numberOfCities)
y = x+np.random.rand(numberOfCities)
z=[3360780/n, 2257227/n, 8468553/n, 418253/n, 747346/n, 3132345/n, 568599/n,  349075/n, 2245453/n ]
names=['Rawalpindi', 'Gujranwala', 'Lahore', 'Sahiwal', 'Sargodha', 'Faisalabad', 'Bahawalpur', 'D G Khan', 'Multan']
colorChoice=['green', 'blue', 'yellow', 'cyan', 'grey', 'black', 'lightblue', 'brown', 'violet']

plt.figure(figsize = (15,10)) 
for i in range(numberOfCities):
    plt.scatter(x[i], y[i], s=z[i], alpha=0.5, label=names[i])

plt.legend(loc="upper left",numpoints=10,markerscale=0.1)
#plt.xlabel("the X axis")
#plt.ylabel("the Y axis")
plt.title("A colored bubble plot of Punjab main Cities")
plt.show()

# %%
#libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

#Data
n=100
areaOfCities=[494, 149.541917, 665.319354, 34.814103,54.61437, 183.417513, 66.312534, 27.770952, 186.878427]
Population=[3360780, 2257227, 8468553, 418253, 747346, 3132345, 568599,  349075, 2245453]
numberOfCities=9
x = np.random.rand(numberOfCities)
y = x+np.random.rand(numberOfCities)
names=['Rawalpindi', 'Gujranwala', 'Lahore', 'Sahiwal', 'Sargodha', 'Faisalabad', 'Bahawalpur', 'D G Khan', 'Multan']
colorChoice=['green', 'blue', 'yellow', 'cyan', 'lightgreen', 'black', 'lightblue', 'brown', 'grey']
plt.figure(figsize = (15,10)) 
for i in range(numberOfCities):
    plt.scatter(x[i], y[i], s=(Population[i]/areaOfCities[i]), alpha=0.7, label=names[i], color=colorChoice[i])

plt.legend(loc="upper left",numpoints=10,markerscale=0.1)
#plt.xlabel("the X axis")
#plt.ylabel("the Y axis")
plt.title("A colored bubble plot of Population per Area in Punjab")
plt.show()

# %%
#libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

#Data
n=100
areaOfCities=[494, 149.541917, 665.319354, 34.814103,54.61437, 183.417513, 66.312534, 27.770952, 186.878427]
Population=[3360780, 2257227, 8468553, 418253, 747346, 3132345, 568599,  349075, 2245453]
numberOfCities=9
x = np.random.rand(numberOfCities)
y = x+np.random.rand(numberOfCities)
names=['Rawalpindi', 'Gujranwala', 'Lahore', 'Sahiwal', 'Sargodha', 'Faisalabad', 'Bahawalpur', 'D G Khan', 'Multan']
colorChoice=['green', 'blue', 'yellow', 'cyan', 'lightgreen', 'black', 'lightblue', 'brown', 'grey']
plt.figure(figsize = (15,10)) 
for i in range(numberOfCities):
    plt.scatter(Population[i], areaOfCities[i], s=(Population[i]/areaOfCities[i]), alpha=0.7, label=names[i], color=colorChoice[i])

    
for i in range(numberOfCities):
    s=(Population[i]/areaOfCities[i])
    #print(s)

plt.legend(loc="upper left",numpoints=10,markerscale=0.1)
plt.xlabel("Population")
plt.ylabel("Square Area")
plt.title("A colored bubble plot of Population per Area in Punjab")
plt.show()
