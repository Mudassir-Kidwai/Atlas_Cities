# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Create a dataset:
df=pd.DataFrame({
 'x' : [3360780, 2257227, 8468553, 418253, 747346, 3132345, 568599,  349075, 2245453],
'y' : [494, 149.541917, 665.319354, 34.814103,54.61437, 183.417513, 66.312534, 27.770952, 186.878427]
})
plt.figure(figsize = (10,5)) 

plt.plot( 'x','y', data=df, linestyle='none', marker='o')

plt.title("Scatter plot of Population per Area in Punjab")
plt.show()
# Out:
# C:\Users\Mudassir Kidwai\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: Second argument 'y' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#   del sys.path[0]
